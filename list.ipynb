# %%
#str.split(sep=none,maxsplit=-1)
retuns a list[] of substring (words by spliting the string at 
occurences of separator sep)

# %%
our_slogn ="lern Data Engineering with real-time projects"
_stack = "Azure Devops ,python ,sql,git"
institute="Edukron"

# %%
#sliptting slogan by whitespacesa(default)
words=our_slogn.split()

# %%
len(words)
# Out:
# 6

# %%
type(words)
# Out:
# list

# %%
our_slogn
# Out:
# 'lern Data Engineering with real-time projects'

# %%
type(our_slogn)
# Out:
# str

# %%
_stack
# Out:
# 'Azure Devops ,python ,sql,git'

# %%
words
# Out:
# ['lern', 'Data', 'Engineering', 'with', 'real-time', 'projects']

# %%
#splitting teck by come
_stsck="Azure Devops ,python ,sql,git"
skills=_stack.split(',')

# %%
skills
# Out:
# ['Azure Devops ', 'python ', 'sql', 'git']

# %%
type(skills)
# Out:
# list

# %%
len(skills)
# Out:
# 4

# %%
#spliting institute name by char "k"
inatitute="Edukron"
institute.split("k")
# Out:
# ['Edu', 'ron']

# %%
ects"our_slogn ="lern Data Engineering with real-time proj

# %%
our_slogn ="lern Data Engineering with real-time projects"
slipted=our_slogn.split(maxsplit=1)
slipted
# Out:
# ['lern', 'Data Engineering with real-time projects']

# %%
slipted=our_slogn.split(maxsplit=6)
slipted
# Out:
# ['lern', 'Data', 'Engineering', 'with', 'real-time', 'projects']

# %%
slipted=our_slogn.split(maxsplit=6)
slipted
# Out:
# ['lern', 'Data', 'Engineering', 'with', 'real-time', 'projects']

# %%
splitted=our_slogn.split(maxsplit=3)
splitted
# Out:
# ['lern', 'Data', 'Engineering', 'with real-time projects']

# %%
len(splitted)
# Out:
# 4

# %%
multi_space="Azure   Devops   python"

# %%
multi_space
# Out:
# 'Azure   Devops   python'

# %%
lst=['Azure','Devops','python']

# %%
lst[0]
lst[2]
# Out:
# 'python'

# %%
lst[1]="whatever"

# %%
lst
# Out:
# ['Azure', 'whatever', 'python']

# %%
#str.join(iterable) passing list of strings.
the opposite of split..

# %%
list=['umbrella','ice ','sweters']

# %%
type(list)
len(list)
# Out:
# 3

# %%
list[0]
# Out:
# 'umbrella'

# %%
#join with the string variables by using join var

items="chicken"
char=" ".join(items)
char
# Out:
# 'c h i c k e n'

# %%
list=["Raju","Rani","Mantri"]
sep=','.join(list)
sep
# Out:
# 'Raju,Rani,Mantri'

# %%
list=["Raju","Rani","Mantri"]
sep='_'.join(list)
sep
# Out:
# 'Raju_Rani_Mantri'

# %%
#strats with functions by usesing to the string
## in case of input is not required it give false

course="Datascience"
course_n=course.startswith("Data")
course_n
# Out:
# True

# %%
course="Datascience"
course_n=course.startswith("data")
course_n
# Out:
# False

# %%
#Ends eith string using function
## in case of input is not required it give false
file="jaya.pdf"
file_name=file.endswith(".pdf")
file_name
# Out:
# True

# %%
file="jaya.pdf"
file_name=file.endswith(".ppt")
file_name
# Out:
# False

# %%
# index value finding is there are not in this str 

course_slogan = "Learn Data Engineering with Real-Time Projects"
name=course_slogan.find("Real")
name
# Out:
# 28

# %%
#find index values of given str

course_slogan = "Learn Data Engineering with Real-Time Projects"
name=course_slogan.index("rn")
name
# Out:
# 3

# %% [markdown]
# Datatype List[]
# list are mutable (Changeable ),ordered sequences of items
# they are contain items of different data types,making them verey versatile

# %%
# this thi an empty list
krish_lst=[]
print(type(krish_lst))
# Out:
# <class 'list'>

# %%
Demart_things=["ConnectionError","annousement","eatingthings","liqueds"]

# %%
print(Demart_things)
# Out:
# ['ConnectionError', 'annousement', 'eatingthings', 'liqueds']

# %%
prices=[50,40,70,45,34]
print(type(prices))
# Out:
# <class 'list'>

# %% [markdown]
# indexing and slicing of list

# %%
new_things=Demart_things[0]
last=Demart_things[-1]

# %%
new_things
# Out:
# 'ConnectionError'

# %%
last
# Out:
# 'liqueds'

# %%
print("first count :",new_things)
print("last:",last)
# Out:
# first count : ConnectionError
# last: liqueds

# %% [markdown]
# append and exted... indexing.
# slicing.. replacing..
# to add elements
#
# append(item)
# exted(iterable)list.tuple
# insert(index,item)
# insert an item at a specific index. existing items form that index onwords
# are shifted to the right.modifies the list in place

# %%
our_slogn=["aim","thingd","hardwork"]
new_tasks=["it filed","non-it"]

# %%
#insert "strong aim"at the biginnig..
our_slogn.insert(0,"it filed")

# %%
our_slogn
# Out:
# ['it filed', 'aim', 'thingd', 'hardwork']

# %%
# insert"self introa"on the 2ed index
our_slogn.insert(0,"non-it")

# %%
our_slogn
# Out:
# ['non-it',
#  'it filed',
#  'non-it',
#  'self intro',
#  'aim',
#  'self intro',
#  'thingd',
#  'hardwork']

# %%
#insert "strong aim"at the biginnig..
our_slogn.insert( 0 ,"it filed")

# %%
our_slogn
# Out:
# ['it filed',
#  'non-it',
#  'it filed',
#  'non-it',
#  'self intro',
#  'aim',
#  'self intro',
#  'thingd',
#  'hardwork']

# %%
# insert"self introa"on the 2ed index
our_slogn.insert(1,"non-it")

# %%
our_slogn
# Out:
# ['it filed',
#  'non-it',
#  'non-it',
#  'it filed',
#  'non-it',
#  'self intro',
#  'aim',
#  'self intro',
#  'thingd',
#  'hardwork']

# %%
#_adding high priority task at beginning
priority_task=["deploy app","monitor logs"]
priority_task.insert(0,"fix critical bug")

# %%
priority_task
# Out:
# ['fix critical bug', 'deploy app', 'monitor logs']

# %%
priority_task.insert(2,"nothinng error")

# %%
priority_task
# Out:
# ['fix critical bug', 'deploy app', 'nothinng error', 'monitor logs']

# %%
priority_task.insert(-1,"find that")

# %%
priority_task
# Out:
# ['fix critical bug',
#  'deploy app',
#  'nothinng error',
#  'find that',
#  'monitor logs']

# %%
##numbers adding to the list
numbers=[1,2,3,5]
numbers.insert(3,4)

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
#way; to remove elements from the list
course_n=["pyhtin","data science","cloud insert","devops"]
tools=["pyhton","sql","Git","sql"]

# %%
course_n.remove("devops")

# %%
course_n
# Out:
# ['pyhtin', 'data science', 'cloud insert']

# %%
tools
# Out:
# ['pyhton', 'Git']

# %%
tools=["pyhton", "sql", "Git", "sql"]

# %%
print(tools)
# Out:
# ['pyhton', 'sql', 'Git', 'sql']

# %%
tools.remove("sql")
tools
# Out:
# ['pyhton', 'Git', 'sql']

# %%
tools = ["Python", "SQL", "Git", "SQL"]

# %%
tools.remove("SQL")

# %%
tools
# Out:
# ['Python', 'Git', 'SQL']

# %%
student_count=[350, 450, 380, 420]
student_count.remove(380)

# %%
student_count
# Out:
# [350, 450, 420]

# %%
student_count=[350 , 450 , 380 , 420 , 350]
student_count.remove(450)
student_count
# Out:
# [350, 380, 420, 350]

# %%
student_count.remove(350)
student_count
# Out:
# [380, 420]

# %%
tools = ["Python", "SQL", "Git", "SQL"]
tools.remove("SQL")
tools
# Out:
# ['Python', 'Git', 'SQL']

# %%
tools = ["Python","SQL","Git","SQL"]
tools.remove("SQL")
tools
# Out:
# ['Python', 'Git', 'SQL']

# %%
tools=["python","sql","devops","sql"]

# %%
tools.remove("sql")

# %%
tools
# Out:
# ['python', 'devops', 'sql']

# %%
numbers=[230,450,470,230]

# %%
numbers.remove(230)
numbers
# Out:
# [450, 470, 230]

# %% [markdown]
# # asess ment for this basic structures

# %%
# 1 insert our favert food in given list by using to the append

food=["pizza","burge","pasta" ]

# %%
food.append("chilli Chicken")

# %%
food
# Out:
# ['pizza', 'burge', 'pasta', 'chilli Chicken']

# %%
# 2 add multiple items "green"and "yellow"
colors=["red","blue"]
colors.insert(0,"green") , colors.insert(1,"yellow")
colors
# Out:
# ['green', 'yellow', 'red', 'blue']

# %%
# 3 insert specific position
numbers=[1,2,3,5]
numbers.insert(3,4)

# %%
numbers
# Out:
# [1, 2, 3, 4, 5]

# %%
# 4 REMOVE AN item in this given list
fruits=["apple","banana","mango","grapes"]

# %%
fruits.remove("mango")

# %%
fruits
# Out:
# ['apple', 'banana', 'grapes']

# %%
# 5 remove last item.
items=["pen","book","eraser"]
items
# Out:
# ['pen', 'book', 'eraser']

# %%
items.remove("eraser")
print(items)
# Out:
# ['pen', 'book']

# %%
# 6 find index item.
animals=["cat","dog","lion","tiger"]
animals.index("lion")
# Out:
# 2

# %%
animals=["cat","dog","lion","tiger"]
animals.index("tiger")
# Out:
# 3

# %%
# 7 count occurences in ginven list
nums=[1, 2, 3, 2, 4]
nums.count(2)
# Out:
# 2

# %%
# 8 sort the list .
marks=[85,45,90,60]
marks.sort()
marks
# Out:
# [45, 60, 85, 90]

# %%
# 9 reverse this list.
letters = ["a","b","c","d"]
letters[::-1]
# Out:
# ['d', 'c', 'b', 'a']

# %%
# 10 copy the list
original=[10,20,30]
new_data=original.copy()
new_data
# Out:
# [10, 20, 30]

# %%
# 11 clear the list
data=[1, 2, 3, 4]
data.clear()
data
# Out:
# []

# %%
# 12 Exend a list
list1 = [1, 2]
list2 = [3,4]
list1.extend(list2)
list1
# Out:
# [1, 2, 3, 4]
