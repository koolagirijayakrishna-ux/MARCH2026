# %%
# Question: Count vowels in the string "Hello World"
print("SOLVED EXAMPLE:")
print("Count vowels in the string 'Hello World'")
text = "Hello World"
vowels = "aeiouAEIOU"
count = sum(1 for char in text if char in vowels)
print(f"String: {text}")
print(f"Number of vowels: {count}")
print("-" * 50)
# Out:
# SOLVED EXAMPLE:
# Count vowels in the string 'Hello World'
# String: Hello World
# Number of vowels: 3
# --------------------------------------------------

# %%
# 1: Reverse the string "Python Programming"

string_na = "python programing"
lenth = len(string_na)
lenth
reverse = string_na[::-1]
print(f' REverse of string is : {reverse}')
# Out:
#  REverse of string is : gnimargorp nohtyp

# %%
# 2: Check if "racecar" is a palindrome

text = "racecar"

if text == text[::-1]:
    print("is a palyndrome")
else:
        print("not a palyndrome")
# Out:
# is a palyndrome

# %%
#  3: Count the number of words in "Python is a great programming language"

text = "Python is a great programming language"
lengn_w = text.split()
lengn_w
count = len(lengn_w)
print(f' Count of the number of words in : {count}')
# Out:
#  Count of the number of words in : 6

# %%
# 4: Convert "hello world" to title case
text = "hello world"
result = text.title()
print(f' Convert the title card is : {result}')
# Out:
#  Convert the title card is : Hello World

# %%
# 5: Find the length of string "Data Science"

word = "Data Science"
count = len(word)
print(f'lenght of string is : {count}')
# Out:
# lenght of string is : 12

# %%
# 6: Replace all spaces with underscores in "Machine Learning"

text = "Machine Learning"
result = text.replace(" ","_")
print(f' Replace all spaces with some char : {result}')
# Out:
#  Replace all spaces with some char : Machine_Learning

# %%
# 7: Check if "python" is in "Python Programming Language"

words = "Python Programming Language"
if"Python" in words:
    print("word is found")
else:
    print("word is not found")
# Out:
# word is found

# %%
# 8: Extract the first 5 characters from "Artificial Intelligence"

words = "Artificial Intelligence"
results = words[:5]
print(f'Exctracting the first 5 chrs :  {results}')
# Out:
# Exctracting the first 5 chrs :  Artif

# %%
# 9: Convert "UPPERCASE" to lowercase

text = "UPPERCASE"
results = text.lower()
print(f' converted in to :  {results}')
# Out:
#  converted in to :  uppercase

# %%
# 10: Remove all vowels from "Computer Science"

word = "Computer Science"
resul = ""
for ch in word:
    if ch.lower() not in "aeiou":
        resul += ch

print(resul)
# Out:
# Cmptr Scnc

# %%
# 11: Find the most frequent character in "mississippi"

text = "mississippi"
freq = {}
for ch in text:
    freq[ch] = freq.get(ch, 0) + 1

max_count = max (freq.values())


for ch in freq:
    if freq[ch]== max_count:
        print(ch, "-->",max_count)
# Out:
# i --> 4
# s --> 4

# %%
#  12: Check if two strings are anagrams: "listen" and "silent"

s1 = "listen"
s2 = "silent"

if sorted(s1)== sorted(s2):
    print("Anargram")
else:
    print("Not Anargram")
# Out:
# Anargram

# %%
# 14: Count consonants in "Hello World"
word = "Hello World"
count = 0
for ch in word:
    if ch. isalpha()and ch.lower()not in"aioue":
        count += 1

print("cousonants: ",count)
# Out:
# cousonants:  7

# %%
# 15: Find the longest word in "Python is a programming language"
word = "Python is a programming language"
words = word.split()
longest = max(words,key=len)
print("Largest word :",longest)
# Out:
# Largest word : programming

# %%
# 16: Remove all punctuation from "Hello, World! How are you?"

word = "Hello, World! How are you?"
resul = ""
for ch in word:
    if ch.isalnum() or ch.isspace():
        resul += ch
print(resul)
# Out:
# Hello World How are you

# %%
# 17: Check if string starts with "Python"
word = "Python ashdkshiu"
 
if word.startswith("python"):
    print("yes it is starts with python")
else:
        print("no")
# Out:
# no

# %%
# 18: Find the index of first occurrence of 'o' in "Hello World"

word = "Hello World"
results = word.find("o")
print(results)
# Out:
# -1

# %%
# 19: Split string "apple,banana,orange" by comma
words = "apple,banana,orange"
results = words.split(",")
print(results)
# Out:
# ['apple', 'banana', 'orange']

# %%
# 20: Join list ['Python', 'is', 'awesome'] with spaces

words = 'Python', 'is', 'awesome'
results = " ".join(words)
print(results)
# Out:
# Python is awesome

# %%
# 21: Check if string contains only digits: "12345"
digits = "12345"
results = digits.isdigit()
print(results)
# Out:
# True

# %%
# 22: Check if string contains only letters: "HelloWorld"

word = "HelloWorld"
results = word . isalpha()
print(results)
# Out:
# True

# %%
# 23: Convert "hello world" to "hElLo WoRlD" (alternating case)

word = "hello world"
result = ""
for i in range(len(word)):
    if i% 2== 0:
        result +=word[i].lower()
    else:
        result +=word[i].upper()

print(result)
# Out:
# hElLo wOrLd

# %%
# 24: Find all positions of 'a' in "banana"
word = "banana"
result =[]
for i in range(len(word)):
    if word[i]=="a":
        result .append(i)
print(result)
# Out:
# [1, 3, 5]

# %%
#  25: Remove leading and trailing whitespace from "  Hello World  "
word = "  Hello World  "
results = "".join(word.split())
print(results)
# Out:
# HelloWorld

# %%
# 26: Check if string ends with "ing": "programming"
word = "programming"
if word .endswith("ing"):
    print("Yes ends with ing ")
else:
    print("no")
# Out:
# Yes ends with ing

# %%
# 27: Replace first occurrence of 'o' with '0' in "Hello World"

# %%
# 27: Replace first occurrence of 'o' with '0' in "Hello World"

word = "Hello World"
result = word.replace("o","0",)
print(result)
# Out:
# Hell0 W0rld

# %%
#  28: Find the shortest word in "Python is a programming language"

word = "Python is a programming language"
words = word.split()
result = min(words, key=len)
print(result)
# Out:
# a

# %%
# 29: Count words that start with 'p' in "Python programming is powerful" 

word = "python programming is powerful"
words = word.split()
count = 0
for word in words:
    if word.startswith("p"):
        count += 1
print(count)
# Out:
# 3

# %%
# 30: Reverse words in "Hello World Python"

word = "Hello World Python"

words = word.split()
results = ''.join (words[::-1])
print(results)
# Out:
# PythonWorldHello
