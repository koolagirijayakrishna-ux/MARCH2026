# %%
# Dictionary

# %%
### set
# create a set
my_set = {1,2,3}
empty_set = set()
  

# adding
my_set.add(4)

# %%
my_set.update([5,6])

# %%
my_set
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
#  Removing
my_set.remove(1)

# %%
my_set
# Out:
# {2, 3, 4, 5, 6}

# %%
# types of removing
my_set.discard(2)

# %%
my_set.remove(2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 my_set.remove(2)
#
# KeyError: 2

# %%
my_set.clear()
my_set
# Out:
# set()

# %%
## Uinon # Intersection # difference # symetric difference(operation)
## comparisoons
# set.2 is subset(set2)
# set1. is superset(set2)
# set1. is disjoin(set2)

# %% [markdown]
# ## python Dictionary-
#
#  A dictionary is a collection data type in python that strores data in key - value pairs.
#  Think of it like a real dictionary wher you look up a word(key ) to find its meaning (value)

# %%
set = { value1,valu2,value3}

dict = { name: value, key : value, key:value}

dic = {name: phonenumber,lohit : 812123164}

# %%
## chars of dicstionary

# 1. key-value paris

# Every item in a dict consists of of two parts:
# a key (identifoer)
# A value (Data associated with that key)

student = {
    "name": "kiran",
     "age" : 25,
     "grade": "A"
}

# %%
student
# Out:
# {'name': 'kiran', 'age': 25, 'grade': 'A'}

# %%
type(student)
# Out:
# dict

# %%
## 2. key must be unique

student = student= {
     "name": "kiran",
     "age" : 25,
     "grade": "krishna"   # this overwrite the first "name"

}

# %%
student
# Out:
# {'name': 'kiran', 'age': 25, 'grade': 'A'}

# %%
###  key must be immutable

# can be = string, numbers, tuple.
# connot be = list,sets,dict
# validkeys

valid_dict={
    "name": "Alice",
    42 : "Answer",
    (1,2): "Tuple",
    True: "Boolean"
}
valid_dict
# Out:
# {'name': 'Alice', 42: 'Answer', (1, 2): 'Tuple', True: 'Boolean'}

# %%
# Invalis keys

invalid_dict = {[1,2]: "list"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 # Invalis keys
#       2
# ----> 3 invalid_dict = {[1,2]: "list"}
#
# TypeError: cannot use 'list' as a dict key (unhashable type: 'list')

# %%
## value can be any thing
# atring, numbers,list, set,other dicts..

# %%
valid_dict = {
    "name" : ["alice"],
    23 :  ("anwer"),
    (1,2) : {"yuple"},
    True : "boolean"
}

# %%
valid_dict
# Out:
# {'name': ['alice'], 23: 'anwer', (1, 2): {'yuple'}, True: 'boolean'}

# %%
# multiple (changeable)

# Creating dict

  empty_set = {}
  my_dictionary = {1: "value","vlaue":1}

# %%
## using constructor

person = dict(name = "Alice", age = 25, city = "Mumbai")

# %%
person
# Out:
# {'name': 'Alice', 'age': 25, 'city': 'Mumbai'}

# %%
type(person)
# Out:
# dict

# %%
## from a list of tuple

pair = [("name","somename"), ("age",22),("city","mumbai")]
type(pair)
# Out:
# list

# %%
person = dict(pair)

# %%
person
# Out:
# {'name': 'somename', 'age': 22, 'city': 'mumbai'}

# %%
type(person)
# Out:
# dict

# %%
## using fromkey( ) - same value for multiple keys

key =["name", "age","city"]
default_values = dict.fromkeys( key,"unknown")

# %%
default_values
# Out:
# {'name': 'unknown', 'age': 'unknown', 'city': 'unknown'}

# %%
type(default_values)
# Out:
# dict

# %%
## Accending dictionary Items

person = { 'name': 'Alice', 'age':34,'city':'mumbai'}
person["name"]
person["city"]
# Out:
# 'mumbai'

# %%
print(person["name"],person["age"],person["city"])
# Out:
# Alice 34 mumbai

# %%
person["Address"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 person["Address"]
#
# KeyError: 'Address'

# %%
# using get()  method(safer)

person
# Out:
# {'name': 'Alice', 'age': 34, 'city': 'mumbai'}

# %%
person.get("name")
# Out:
# 'Alice'

# %%
person.get("age")
# Out:
# 34

# %%
## provide a default value

person.get("Address","retuns given default value")
# Out:
# 'retuns given default value'

# %%
## Accesing Nested Dictionareus

student = {
    "name": "Alice",
    "age": 23,
    "address":{
        "city": "Mumbai",
         "pincode":517324
}
}

# %%
student
# Out:
# {'name': 'Alice', 'age': 23, 'address': {'city': 'Mumbai', 'pincode': 517324}}

# %%
student["address"]["city"]
# Out:
# 'Mumbai'

# %%
student["address"]["pincode"]
# Out:
# 517324

# %%
# adding modifying items
# Adding new items 

person = {"name ":"Alice","age":23}

# %%
person
# Out:
# {'name ': 'Alice', 'age': 23}

# %%
person["city"] = "Mumbai"

# %%
person
# Out:
# {'name ': 'Alice', 'age': 23, 'city': 'Mumbai'}

# %%
person["phone"] = 8688234123

# %%
person
# Out:
# {'name ': 'Alice', 'age': 23, 'city': 'Mumbai', 'phone': 8688234123}

# %%
# midify Existing items

person['age']
# Out:
# 23

# %%
person['age'] = 23

# %%
person
# Out:
# {'name ': 'Alice', 'age': 23, 'city': 'Mumbai', 'phone': 8688234123}

# %%
person["city"]
# Out:
# 'Mumbai'

# %%
person["city"] = "Delhi"

# %%
person
# Out:
# {'name ': 'Alice', 'age': 23, 'city': 'Delhi', 'phone': 8688234123}

# %%
## using update() - add / modify multiple items..
person = {"name": "Alice","age": 23}

# adding multiple items..

person.update({"city": "Mumbai","phone":1234567891})

# %%
person.update({"age": 23, "name": "Amit"})

# %%
person
# Out:
# {'name': 'Amit', 'age': 23, 'city': 'Mumbai'}

# %%
del person ["phone"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 del person ["phone"]
#
# KeyError: 'phone'

# %%
person
# Out:
# {'name': 'Amit', 'age': 23, 'city': 'Mumbai'}

# %%
## using pop(): Rerun removed values

# Removed and retuns value
person = {'name': 'Amit', 'age':23, 'city': 'mubai'}

# %%
age = person.pop("age")
age
# Out:
# 23

# %%
person
# Out:
# {'name': 'Amit', 'age': 23, 'city': 'mubai'}

# %%
# with default value(if key doesn't exist)
phone= phone.pop("phone")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[62], line 2
#       1 # with default value(if key doesn't exist)
# ----> 2 phone= phone.pop("phone")
#
# NameError: name 'phone' is not defined

# %%
phone
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 phone
#
# NameError: name 'phone' is not defined

# %%
person
# Out:
# {'name': 'Amit', 'age': 23, 'city': 'mubai'}

# %%
phone_removed = person.pop("phone", "not found")

# %%
phone_removed
# Out:
# 'not found'

# %%
# using pipitem()-Removed Last Item

person = {'name':'Amit','age': 23, 'city':'mubai',}

item = person.popitem()

# %%
type(item)
# Out:
# tuple

# %%
item1 = person.popitem()

# %%
item1
# Out:
# ('age', 23)

# %%
empty = {}

# %%
type(empty)
item4 = empty.popitem()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[77], line 2
#       1 type(empty)
# ----> 2 item4 = empty.popitem()
#
# KeyError: 'popitem(): dictionary is empty'

# %%
person = {'name':'Amit', 'age':23, 'city':'mumbai'}
print(person)
person
# Out:
# {'name': 'Amit', 'age': 23, 'city': 'mumbai'}
# {'name': 'Amit', 'age': 23, 'city': 'mumbai'}

# %%
s
