# %%
import pandas as pd

# %%
pd.DataFrame([1,2,3],columns=['A'],index=['A','B','c'])
# Out:
#    A
# A  1
# B  2
# c  3

# %%
pd.DataFrame((1,2,3))
# Out:
#    0
# 0  1
# 1  2
# 2  3

# %%
pd.DataFrame({"Moths":["jan","Fed"],"Sales":[20,40]})
# Out:
#   Moths  Sales
# 0   jan     20
# 1   Fed     40

# %%
import numpy as np
np.random.seed(121)
df =pd.DataFrame(np.random.randint(0,10,(3,3)))

# %%
"A B C".split()
# Out:
# ['A', 'B', 'C']

# %%
np.random.seed(121)
df = pd.DataFrame(np.random.randint(0,10(3,3)),columns="A B C".split(),index='P Q R'.split())
df
# Out:
# <>:2: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
# C:\Users\Jaya krishna\AppData\Local\Temp\ipykernel_23708\2280823916.py:2: SyntaxWarning: 'int' object is not callable; perhaps you missed a comma?
#   df = pd.DataFrame(np.random.randint(0,10(3,3)),columns="A B C".split(),index='P Q R'.split())
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 2
#       1 np.random.seed(121)
# ----> 2 df = pd.DataFrame(np.random.randint(0,10(3,3)),columns="A B C".split(),index='P Q R'.split())
#       3 df
#
# TypeError: 'int' object is not callable

# %%
df
# Out:
#    0  1  2
# 0  2  5  8
# 1  4  1  4
# 2  3  0  2

# %%
# Out:
#   Cell In[6], line 1
#     pip install pandas
#         ^
# SyntaxError: invalid syntax
# ...
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
# ...

# %%
import pandas as pd
df= pd.read_csv(r"C:\Users\Jaya krishna\OneDrive\New folder\pandas\Superstore sales dataset.csv")

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.columns
df.head(2)
df.tail()
df.index
# Out:
# RangeIndex(start=0, stop=9994, step=1)

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='str')

# %%
df[['Row ID','Order ID','Sales']].head(2)
# Out:
#    Row ID        Order ID   Sales
# 0       1  CA-2016-152156  261.96
# 1       2  CA-2016-152156  731.94

# %%
df.iloc[rows,columns]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 df.iloc[rows,columns]
#
# NameError: name 'rows' is not defined

# %%
df.iloc[2:8,[2,5,7]]
# Out:
#    Order Date Customer ID    Segment
# 2  12-06-2016    DV-13045  Corporate
# 3  11-10-2015    SO-20335   Consumer
# 4  11-10-2015    SO-20335   Consumer
# 5  09-06-2014    BH-11710   Consumer
# 6  09-06-2014    BH-11710   Consumer
# 7  09-06-2014    BH-11710   Consumer

# %%
df.dtypes
# Out:
# Row ID             int64
# Order ID             str
# Order Date           str
# Ship Date            str
# Ship Mode            str
# Customer ID          str
# Customer Name        str
# Segment              str
# Country              str
# City                 str
# State                str
# Postal Code        int64
# Region               str
# Product ID           str
# Category             str
# Sub-Category         str
# Product Name         str
# Sales            float64
# Quantity           int64
# Discount         float64
# Profit           float64
# dtype: object

# %%
import numpy as np

# %%
np.iinfo(np.int8)
# Out:
# iinfo(min=-128, max=127, dtype=int8)

# %%
np.finfo(np.float16).min
# Out:
# np.float16(-6.55e+04)

# %%
df.select_dtypes(include=['int64','float64']).head(2)
# Out:
#    Row ID  Postal Code   Sales  Quantity  Discount    Profit
# 0       1        42420  261.96         2       0.0   41.9136
# 1       2        42420  731.94         3       0.0  219.5820

# %%
df.select_dtypes(include=['str']).shape
# Out:
# (9994, 15)

# %%
df.shape
# Out:
# (9994, 21)

# %%
df.select_dtypes(include=['int64','float64']).shape
# Out:
# (9994, 6)

# %%
subset_df=df.iloc[0:5,0:5].copy()

# %%
subset_df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode'], dtype='str')

# %%
subset_df[['Row ID','Order ID','Ship Mode','Ship Date']].min()
# Out:
# Row ID                    1
# Order ID     CA-2016-138688
# Ship Mode      Second Class
# Ship Date        11-11-2016
# dtype: object

# %%
df[['Sales']].mean()
# Out:
# Sales    229.858001
# dtype: float64

# %%
df['Ship Mode'].str.upper().head(2)
# Out:
# 0    SECOND CLASS
# 1    SECOND CLASS
# Name: Ship Mode, dtype: str

# %%
df['Ship Mode'].str.lower().head(2)
# Out:
# 0    second class
# 1    second class
# Name: Ship Mode, dtype: str

# %%
df['Ship Mode'].str.capitalize().head(2)
# Out:
# 0    Second class
# 1    Second class
# Name: Ship Mode, dtype: str

# %%
df['Ship Mode'].str.title().head(2)
# Out:
# 0    Second Class
# 1    Second Class
# Name: Ship Mode, dtype: str

# %%
"data Science".capitalize()
# Out:
# 'Data science'

# %%
df['Ship Mode'].str.len().head(2)
# Out:
# 0    12
# 1    12
# Name: Ship Mode, dtype: int64

# %%
df['Ship Mode'].str.strip().head(2)
# Out:
# 0    Second Class
# 1    Second Class
# Name: Ship Mode, dtype: str

# %%
" data ".strip()
# Out:
# 'data'

# %%
df['Ship Mode'].str.lstrip().head(2)
# Out:
# 0    Second Class
# 1    Second Class
# Name: Ship Mode, dtype: str

# %%
df['Ship Mode'].str.rstrip().head(2)
# Out:
# 0    Second Class
# 1    Second Class
# Name: Ship Mode, dtype: str

# %%
df['Ship Mode'].str.split(" ").str[0]
# Out:
# 0         Second
# 1         Second
# 2         Second
# 3       Standard
# 4       Standard
#           ...
# 9989      Second
# 9990    Standard
# 9991    Standard
# 9992    Standard
# 9993      Second
# Name: Ship Mode, Length: 9994, dtype: object

# %%
"91-733833".split("-")
# Out:
# ['91', '733833']

# %%
"data science".split("a")
# Out:
# ['d', 't', ' science']

# %%
df['Ship Mode'].str.count("Second")
# Out:
# 0       1
# 1       1
# 2       1
# 3       0
# 4       0
#        ..
# 9989    1
# 9990    0
# 9991    0
# 9992    0
# 9993    1
# Name: Ship Mode, Length: 9994, dtype: int64

# %%
df["Ship Mode"].str.pad(width = 20,side='left',fillchar="-")
# Out:
# 0       --------Second Class
# 1       --------Second Class
# 2       --------Second Class
# 3       ------Standard Class
# 4       ------Standard Class
#                 ...
# 9989    --------Second Class
# 9990    ------Standard Class
# 9991    ------Standard Class
# 9992    ------Standard Class
# 9993    --------Second Class
# Name: Ship Mode, Length: 9994, dtype: str

# %%
## creating  preprocessing pipeline for the data

import pandas as pd

class preprocessingPipeline:
    def __int__(self,df):
        self.df = df


    # handling null values
    def null_value_treatment(self,tv):
        data = self.df
        ## calculating null values percenteages
        null_value_percentage = ((data.isna().sum())/data.shape[0])*100

        # droping colums whose null value threshold is  grater then
        columns_dropped = null_value_percentage[null_value_percentage >(tv * 100)].index
        columns_dropped = null_value_percentage[null_value_percentage< (tv *100)].index
        data = data.drop(columns =columns_dropped)
        print(data.shape,len(columns_dropped),len(columns_not_dropped))

        ## Return the final data
        return data
    ## optimising memory
    def memory_optimisation(self,df):
        pass

    ## handling outliers
    def outlier_treatment(self,df):
        pass

    ## enconding
    def categorial_encoding(self,df):
        pass

    ## Data splitting
    def Data_splitting(self,df):
        pass
    ## Exporatory data analysis
    def EDA(sekf,df):
        pass
