# %%
# FLOAT DATATYPE ASSIGNMENT
# =========================

# SOLVED EXAMPLE
# --------------
# Question: Calculate the area of a circle with radius 5.5
print("SOLVED EXAMPLE:")
print("Calculate the area of a circle with radius 5.5")
import math
radius = 5.5
area = math.pi * radius ** 2
print(f"Radius: {radius}")
print(f"Area: {area:.2f}")
print("-" * 50)
# Out:
# SOLVED EXAMPLE:
# Calculate the area of a circle with radius 5.5
# Radius: 5.5
# Area: 95.03
# --------------------------------------------------

# %%
# 1: Calculate the average of 3.14, 2.718, 1.618, 0.577


num = [3.14, 2.718, 1.618, 0.577]
result = sum(num)/len(num)
print(f' the caluctions of average :   {result}')
# Out:
#  the caluctions of average :   2.01325

# %%
# 2: Convert 98.6 Fahrenheit to Celsius (F = C * 9/5 + 32)


num = 98.6

f = 98.6 * 9/5  + 32

print(f' The fahrenheit is :  {f}')
# Out:
#  The fahrenheit is :  209.48

# %%
# 3: Calculate the compound interest on $1000 at 5.5% for 3 years



p = 1000
r = 5.5*1/100
r
t = 3 
n = 1

a  = p*(1 + r/n)**3/n
print(f' Calucation of the compound interest is :{a}')
# Out:
#  Calucation of the compound interest is :1174.2413749999998

# %%
#  4: Find the hypotenuse of a right triangle with sides 3.5 and 4.2

a = 3.5
b = 4.2

c = math.sqrt(a**2 + b**2)

print(f' THE hypotenuse of : {c}')
# Out:
#  THE hypotenuse of : 5.4671747731346585

# %%
# Whith out ussing maths opperation

a= 3.5
b= 4.3
c = (a**2 + b**2) ** 0.5
print(c)
# Out:
# 5.544366510251645

# %%
# 5: Calculate the volume of a sphere with radius 7.8

r = 7.8
py = 3.141
v = (4/3*py)*(7.8)**3
print(f' The volume of sphere is: {v}')
# Out:
#  The volume of sphere is: 1987.4237759999996

# %%
# 6: Round 3.14159 to 3 decimal places

num = 3.14159

round_num = round(num,3)
print(round_num)
# Out:
# 3.142

# %%
# 7: Calculate the percentage: 45 out of 67

a = 45
b = 67
p = 100

percentage = (a/b) * p

print(f' calculate the percentage : {percentage}')
# Out:
#  calculate the percentage : 67.16417910447761

# %%
#  8: Find the square root of 23.456

a = 23.456
square = 23.456 ** 0.5
print(f' The square root of 23.456 is : {square}')
# Out:
#  The square root of 23.456 is : 4.843139477652899

# %%
# 9: Calculate the simple interest: Principal=2500, Rate=6.5%, Time=2.5 years

p = 2500
r = 6.5*1/100
r
t = 2.5

result = (p*t*r)## due to rate is already decimal
print(f' simpe intrest is : {result}')
# Out:
#  simpe intrest is : 406.25

# %%
# 10: Convert 45.7 degrees to radians
   


d = 45.7
py = 3.141/180
py
redius = d * py
print(f' Covert degree to radians : {redius}')
# Out:
#  Covert degree to radians : 0.7974650000000001
