# %% [markdown]
# # string functions
# given below functions

# %%
name="jaya krishna"
age="22"
course_slogan="data science"

# %%
print(name+ age+course_slogan)
# Out:
# jaya krishna22data science

# %%
#repetition
print(name*10)
# Out:
# jaya krishnajaya krishnajaya krishnajaya krishnajaya krishnajaya krishnajaya krishnajaya krishnajaya krishnajaya krishna

# %%
#lenth function

print(len (name))
# Out:
# 12

# %%
#indexing
#first_char=name[0]
print(name[0])
# Out:
# j

# %%
#first_char=name[-1]
print(name[-2])
# Out:
# n

# %%
# slicing
print(name[1:-1])
# Out:
# aya krishn

# %%
#string lower cases
name.lower()
# Out:
# 'jaya krishna'

# %%
#string upper cases
name.upper()
# Out:
# 'JAYA KRISHNA'

# %%
#string upper cases 
institute="educron"

# %%
institute.upper()
# Out:
# 'EDUCRON'

# %%
#it will be a exiguited both lines 

print(institute.lower())
print(institute.upper())
# Out:
# educron
# EDUCRON

# %%
#INthis code will exiguted only last line of given data
institute.lower()
institute.upper()
# Out:
# 'EDUCRON'

# %%
name="jaya krishna"
course_name="data sciece"

# %%
#revers order name will print


print(name[::-1])
# Out:
# anhsirk ayaj

# %%
print(len(course_name))
# Out:
# 11

# %%
#revers order prints
print( course_name[:: -1])
# Out:
# eceics atad
